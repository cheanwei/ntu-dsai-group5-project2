# %% [markdown]
# # 03 — Product and seller performance
#
# Top categories, category revenue concentration, seller distribution, freight as
# a share of revenue.
#
# Read `fct_order_items` joined to `dim_product` and `dim_seller`. Do **not**
# join `fct_payments` in: payments are at order grain and items at line grain, so
# the join multiplies `payment_value` by the number of lines and inflates revenue
# (§5.2).
#
# Owner: lane B2.

# %%
import os

import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import create_engine

load_dotenv("../.env")

# Marts only. The dialect keeps the warehouse swappable (§9).
engine = create_engine(f"bigquery://{os.environ['GCP_PROJECT']}/olist_marts")
