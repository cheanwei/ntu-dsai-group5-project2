# %% [markdown]
# # 04 — Customer segmentation
#
# RFM segmentation, repeat-purchase behaviour, geographic concentration.
#
# **Key discipline (§5.2).** Segment on `dim_customer.customer_key`, which is
# `customer_unique_id`. `customer_id` is a per-order surrogate; using it yields
# ~99k customers who each ordered once and the false finding that Olist has no
# repeat business. The true figure is ~96k unique customers with roughly 3%
# repeating. Any RFM built on the wrong key is meaningless.
#
# Owner: lane B2.

# %%
import os

import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import create_engine

load_dotenv("../.env")

# Marts only. The dialect keeps the warehouse swappable (§9).
engine = create_engine(f"bigquery://{os.environ['GCP_PROJECT']}/olist_marts")
